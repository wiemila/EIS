# %% [markdown]
# <a href="https://colab.research.google.com/github/wiemila/EIS/blob/main/PStracexls%20toCh1df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0414b0d9-645b-4d37-9d94-1707b8ff6f5a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0414b0d9-645b-4d37-9d94-1707b8ff6f5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
data = pd.read_excel(io.BytesIO(uploaded['All_exported_30_10_23.xlsx']))

# %%
data.iloc[1:15]
# Out:
#                    Column1                 Column2           Column3  \
# 1             Measurement:  Impedance Spectroscopy               NaN
# 2                   Notes:                     NaN               NaN
# 3           Date and time:     2023-10-30 11:24:39               NaN
# 4   CH 1: Fixed at 7 freqs                     NaN               NaN
# 5                freq / Hz                Time / s       Log(f / Hz)
# 6                      150    0.000999500043690205  2.17609125905568
# 7         124.902473449707    0.000999500043690205  2.09657103881387
# 8         104.004188537598    0.000999500043690205  2.01705082989624
# 9            86.6025390625    0.000999500043690205  1.93753062509665
# 10        72.1124801635742    0.000999500043690205  1.85801043250215
# 11        60.0468482971191    0.000999500043690205  1.77849021734941
# 12                      50    0.000999500043690205  1.69897000433602
# 13                     NaN                     NaN               NaN
# ...

# %%
var_count=len(data)
var_count
# Out:
# 9646

# %%
Where_Ch1=data['Column1'].str.contains('CH 1')

# %%
Where_Ch1[0:10]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Column1, dtype: object

# %%
df_freq1=pd.DataFrame(columns=['Phase_fr1', 'Z_fr1', 'Zi_fr1', 'Zii_fr1', 'Cs_fr1'])
df_freq2=pd.DataFrame(columns=['Phase_fr2', 'Z_fr2', 'Zi_fr2', 'Zii_fr2', 'Cs_fr2'])
df_freq3=pd.DataFrame(columns=['Phase_fr3', 'Z_fr3', 'Zi_fr3', 'Zii_fr3', 'Cs_fr3'])
df_freq4=pd.DataFrame(columns=['Phase_fr4', 'Z_fr4', 'Zi_fr4', 'Zii_fr4', 'Cs_fr4'])
df_freq5=pd.DataFrame(columns=['Phase_fr5', 'Z_fr5', 'Zi_fr5', 'Zii_fr5', 'Cs_fr5'])
df_freq6=pd.DataFrame(columns=['Phase_fr6', 'Z_fr6', 'Zi_fr6', 'Zii_fr6', 'Cs_fr6'])
df_freq7=pd.DataFrame(columns=['Phase_fr7', 'Z_fr7', 'Zi_fr7', 'Zii_fr7', 'Cs_fr7'])

# %%
i=0

# %%
for i in range (var_count):
    if Where_Ch1[i]==True:
      df_freq1.at[i,'Phase_fr1']=data.iloc[i+2,3]
      df_freq1.at[i,'Z_fr1']=data.iloc[i+2,6]
      df_freq1.at[i,'Zi_fr1']=data.iloc[i+2,7]
      df_freq1.at[i,'Zii_fr1']=data.iloc[i+2,8]
      df_freq1.at[i,'Cs_fr1']=data.iloc[i+2,14]
      df_freq2.at[i,'Phase_fr2']=data.iloc[i+3,3]
      df_freq2.at[i,'Z_fr2']=data.iloc[i+3,6]
      df_freq2.at[i,'Zi_fr2']=data.iloc[i+3,7]
      df_freq2.at[i,'Zii_fr2']=data.iloc[i+3,8]
      df_freq2.at[i,'Cs_fr2']=data.iloc[i+3,14]
      df_freq3.at[i,'Phase_fr3']=data.iloc[i+4,3]
      df_freq3.at[i,'Z_fr3']=data.iloc[i+4,6]
      df_freq3.at[i,'Zi_fr3']=data.iloc[i+4,7]
      df_freq3.at[i,'Zii_fr3']=data.iloc[i+4,8]
      df_freq3.at[i,'Cs_fr3']=data.iloc[i+4,14]
      df_freq4.at[i,'Phase_fr4']=data.iloc[i+5,3]
      df_freq4.at[i,'Z_fr4']=data.iloc[i+5,6]
      df_freq4.at[i,'Zi_fr4']=data.iloc[i+5,7]
      df_freq4.at[i,'Zii_fr4']=data.iloc[i+5,8]
      df_freq4.at[i,'Cs_fr4']=data.iloc[i+5,14]
      df_freq5.at[i,'Phase_fr5']=data.iloc[i+6,3]
      df_freq5.at[i,'Z_fr5']=data.iloc[i+6,6]
      df_freq5.at[i,'Zi_fr5']=data.iloc[i+6,7]
      df_freq5.at[i,'Zii_fr5']=data.iloc[i+6,8]
      df_freq5.at[i,'Cs_fr5']=data.iloc[i+6,14]
      df_freq6.at[i,'Phase_fr6']=data.iloc[i+7,3]
      df_freq6.at[i,'Z_fr6']=data.iloc[i+7,6]
      df_freq6.at[i,'Zi_fr6']=data.iloc[i+7,7]
      df_freq6.at[i,'Zii_fr6']=data.iloc[i+7,8]
      df_freq6.at[i,'Cs_fr6']=data.iloc[i+7,14]
      df_freq7.at[i,'Phase_fr7']=data.iloc[i+8,3]
      df_freq7.at[i,'Z_fr7']=data.iloc[i+8,6]
      df_freq7.at[i,'Zi_fr7']=data.iloc[i+8,7]
      df_freq7.at[i,'Zii_fr7']=data.iloc[i+8,8]
      df_freq7.at[i,'Cs_fr7']=data.iloc[i+8,14]
      i=i+1

# %%
df_freq1
# Out:
#              Phase_fr1             Z_fr1            Zi_fr1           Zii_fr1  \
# 4     82.3196511580142  7467.46368632456  997.998837503955  7400.47378394902
# 67     82.526627248438  7536.87980490003  980.287443659138  7472.85713240352
# 130   83.9277224182306  7376.82463446161   780.34227893908  7335.43506653149
# 213   81.7872390557854  8600.93541420048  1228.63823642591  8512.72800477263
# 296   84.4847797183712  9096.39984907769  874.256537615229  9054.28990704062
# ...                ...               ...               ...               ...
# 9233  83.4639779563211  8427.74196363922   959.31177524797  8372.96575435228
# 9316  84.0017821123193  8461.28494594081  884.183376452827  8414.96064715748
# 9399  81.2900305598169  8692.26390858194  1316.29399634374  8592.02083165688
# 9482  79.5633213908875  7801.66766268473  1413.26237453466  7672.59459242474
# 9565  83.1444662229114  8246.57425756696  984.363400133819  8187.61355231444
#
#                     Cs_fr1
# ...

# %%
# Out:
#                               4                67                130   \
# Phase_fr2
# 83.2370547371301  82.3196511580142  82.526627248438  83.9277224182306
# 83.0256231874631  82.3196511580142  82.526627248438  83.9277224182306
# 82.990361789577   82.3196511580142  82.526627248438  83.9277224182306
# 82.5736829429809  82.3196511580142  82.526627248438  83.9277224182306
# 83.1001497985966  82.3196511580142  82.526627248438  83.9277224182306
# ...                            ...              ...               ...
# 83.1988669766224  82.3196511580142  82.526627248438  83.9277224182306
# 84.2913190373965  82.3196511580142  82.526627248438  83.9277224182306
# 80.6912797555654  82.3196511580142  82.526627248438  83.9277224182306
# 81.6891447883882  82.3196511580142  82.526627248438  83.9277224182306
# 83.2438134668192  82.3196511580142  82.526627248438  83.9277224182306
#
#                               213               296               379   \
# Phase_fr2
# ...
