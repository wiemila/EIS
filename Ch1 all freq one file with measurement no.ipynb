# %% [markdown]
# <a href="https://colab.research.google.com/github/wiemila/EIS/blob/main/Ch1%20all%20freq%20one%20file%20with%20measurement%20no.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6f06e0ca-75b5-4ada-873a-1b577796dcbd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f06e0ca-75b5-4ada-873a-1b577796dcbd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
data = pd.read_excel(io.BytesIO(uploaded['All_exported_30_10_23 (1).xlsx']))

# %%
data.iloc[1:15]
# Out:
#                      Column1                 Column2           Column3  \
# 1               Measurement:  Impedance Spectroscopy               NaN
# 2                     Notes:                     NaN               NaN
# 3             Date and time:     2023-10-30 11:24:39               NaN
# 4   CH 1: Fixed at 7 freqs 0                     NaN               NaN
# 5                  freq / Hz                Time / s       Log(f / Hz)
# 6                        150    0.000999500043690205  2.17609125905568
# 7           124.902473449707    0.000999500043690205  2.09657103881387
# 8           104.004188537598    0.000999500043690205  2.01705082989624
# 9              86.6025390625    0.000999500043690205  1.93753062509665
# 10          72.1124801635742    0.000999500043690205  1.85801043250215
# 11          60.0468482971191    0.000999500043690205  1.77849021734941
# 12                        50    0.000999500043690205  1.69897000433602
# ...

# %%
var_count=len(data)
var_count
# Out:
# 9646

# %%
Where_Ch1=data['Column1'].str.contains('CH 1')
Where_Ch2=data['Column1'].str.contains('CH 2')
Where_Ch3=data['Column1'].str.contains('CH 3')
Where_Ch4=data['Column1'].str.contains('CH 4')
Where_Ch5=data['Column1'].str.contains('CH 5')
Where_Ch6=data['Column1'].str.contains('CH 6')
Where_Ch7=data['Column1'].str.contains('CH 7')
Where_Ch8=data['Column1'].str.contains('CH 8')

# %%
Where_Ch1[0:10]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Column1, dtype: object

# %%
df_freqall=pd.DataFrame(columns=['Measurement','Phase_fr1', 'Z_fr1', 'Zi_fr1', 'Zii_fr1', 'Cs_fr1','Phase_fr2', 'Z_fr2', 'Zi_fr2', 'Zii_fr2', 'Cs_fr2','Phase_fr3', 'Z_fr3', 'Zi_fr3', 'Zii_fr3', 'Cs_fr3','Phase_fr4', 'Z_fr4', 'Zi_fr4', 'Zii_fr4', 'Cs_fr4','Phase_fr5', 'Z_fr5', 'Zi_fr5', 'Zii_fr5', 'Cs_fr5','Phase_fr6', 'Z_fr6', 'Zi_fr6', 'Zii_fr6', 'Cs_fr6','Phase_fr7', 'Z_fr7', 'Zi_fr7', 'Zii_fr7', 'Cs_fr7'])

# %%
i=0

# %%
for i in range (var_count):
    if Where_Ch1[i]==True:
      numerki=re.findall(r'\d+', data['Column1'][i])
      df_freqall.at[i,'Measurement']=numerki[-1]
      df_freqall.at[i,'Phase_fr1']=data.iloc[i+2,3]
      df_freqall.at[i,'Z_fr1']=data.iloc[i+2,6]
      df_freqall.at[i,'Zi_fr1']=data.iloc[i+2,7]
      df_freqall.at[i,'Zii_fr1']=data.iloc[i+2,8]
      df_freqall.at[i,'Cs_fr1']=data.iloc[i+2,14]
      df_freqall.at[i,'Phase_fr2']=data.iloc[i+3,3]
      df_freqall.at[i,'Z_fr2']=data.iloc[i+3,6]
      df_freqall.at[i,'Zi_fr2']=data.iloc[i+3,7]
      df_freqall.at[i,'Zii_fr2']=data.iloc[i+3,8]
      df_freqall.at[i,'Cs_fr2']=data.iloc[i+3,14]
      df_freqall.at[i,'Phase_fr3']=data.iloc[i+4,3]
      df_freqall.at[i,'Z_fr3']=data.iloc[i+4,6]
      df_freqall.at[i,'Zi_fr3']=data.iloc[i+4,7]
      df_freqall.at[i,'Zii_fr3']=data.iloc[i+4,8]
      df_freqall.at[i,'Cs_fr3']=data.iloc[i+4,14]
      df_freqall.at[i,'Phase_fr4']=data.iloc[i+5,3]
      df_freqall.at[i,'Z_fr4']=data.iloc[i+5,6]
      df_freqall.at[i,'Zi_fr4']=data.iloc[i+5,7]
      df_freqall.at[i,'Zii_fr4']=data.iloc[i+5,8]
      df_freqall.at[i,'Cs_fr4']=data.iloc[i+5,14]
      df_freqall.at[i,'Phase_fr5']=data.iloc[i+6,3]
      df_freqall.at[i,'Z_fr5']=data.iloc[i+6,6]
      df_freqall.at[i,'Zi_fr5']=data.iloc[i+6,7]
      df_freqall.at[i,'Zii_fr5']=data.iloc[i+6,8]
      df_freqall.at[i,'Cs_fr5']=data.iloc[i+6,14]
      df_freqall.at[i,'Phase_fr6']=data.iloc[i+7,3]
      df_freqall.at[i,'Z_fr6']=data.iloc[i+7,6]
      df_freqall.at[i,'Zi_fr6']=data.iloc[i+7,7]
      df_freqall.at[i,'Zii_fr6']=data.iloc[i+7,8]
      df_freqall.at[i,'Cs_fr6']=data.iloc[i+7,14]
      df_freqall.at[i,'Phase_fr7']=data.iloc[i+8,3]
      df_freqall.at[i,'Z_fr7']=data.iloc[i+8,6]
      df_freqall.at[i,'Zi_fr7']=data.iloc[i+8,7]
      df_freqall.at[i,'Zii_fr7']=data.iloc[i+8,8]
      df_freqall.at[i,'Cs_fr7']=data.iloc[i+8,14]
      i=i+1

# %%
df_freqall
# Out:
#      Measurement         Phase_fr1             Z_fr1            Zi_fr1  \
# 4              0  82.3196511580142  7467.46368632456  997.998837503955
# 67             1   82.526627248438  7536.87980490003  980.287443659138
# 130           10  83.9277224182306  7376.82463446161   780.34227893908
# 213          100  81.7872390557854  8600.93541420048  1228.63823642591
# 296          101  84.4847797183712  9096.39984907769  874.256537615229
# ...          ...               ...               ...               ...
# 9233          95  83.4639779563211  8427.74196363922   959.31177524797
# 9316          96  84.0017821123193  8461.28494594081  884.183376452827
# 9399          97  81.2900305598169  8692.26390858194  1316.29399634374
# 9482          98  79.5633213908875  7801.66766268473  1413.26237453466
# 9565          99  83.1444662229114  8246.57425756696  984.363400133819
#
#                Zii_fr1                Cs_fr1         Phase_fr2  \
# ...

# %%
df_freqall=df_freqall.iloc[:,:].astype(float)
df_freqall.iloc[:,0]
# Out:
# 4         0.0
# 67        1.0
# 130      10.0
# 213     100.0
# 296     101.0
#         ...
# 9233     95.0
# 9316     96.0
# 9399     97.0
# 9482     98.0
# 9565     99.0
# Name: Measurement, Length: 117, dtype: float64

# %%
df_freqall.to_excel("df_freqallex.xlsx")
files.download('df_freqallex.xlsx')

# %%
from google.colab import files
df_freqall.to_csv('df_freqall.csv', encoding = 'utf-8-sig')
files.download('df_freqall.csv')
